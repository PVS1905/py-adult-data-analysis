# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 0
# Read the dataset from csv file & perform data cleaning - remove all rows, which contains `?` in some columns.
# Also check for data correctness (salary & salary $K).

# %%
people = pd.read_csv("/Users/viktor/advanced/py-adult-data-analysis/data/adult.csv", index_col=[0])
people.replace("?", np.nan, inplace=True)
people.dropna(inplace=True)

people.value_counts()
people.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30162 entries, 0 to 32560
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  str
#  2   education       30162 non-null  str
#  3   marital-status  30162 non-null  str
#  4   occupation      30162 non-null  str
#  5   relationship    30162 non-null  str
#  6   race            30162 non-null  str
#  7   sex             30162 non-null  str
#  8   hours-per-week  30162 non-null  int64
#  9   native-country  30162 non-null  str
#  10  salary          30162 non-null  str
#  11  salary K$       30162 non-null  int64
# dtypes: int64(3), str(9)
# memory usage: 3.0 MB

# %% [markdown]
# # Task 1
# Print the count of men and women in the dataset.

# %%
women = people[people["sex"]=="Female"]

people["sex"].value_counts()

# %% [markdown]
# # Task 2
# Find the average age of men in dataset

# %%
male = people[people["sex"]=="Male"]
man = male["age"]
man.mean()

# %% [markdown]
# # Task 3
# Get the percentage of people from Poland (native-country)

# %%
people_country = (people['native-country'] == 'Poland').mean() * 100
# round(len(people[people["native-country"]=="Poland"]) * 100 / len(people["native-country"]), 2)

# %% [markdown]
# # Task 4
# Get the mean and standard deviation of the age for people who earn > 50K per year. After this, get it for those who earn <= 50K.

# %%
people_salary = people[people["salary"]==">50K"]["age"]
people_salary.mean()
people_salary.std()
people_salary_other = people[people["salary"]=="<=50K"]["age"]
people_salary_other.mean()
people_salary_other.std()

# %% [markdown]
# # Task 5
# Check, if there are some people without higher education (education: Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters, Doctorate), but with > 50K salary

# %%
people_education = people[~people["education"].isin(["Bachelors", "Prof-school", "Assoc-acdm", "Masters", "Doctorate", "Assoc-voc"])]
people_education = people_education[people_education["salary"]==">50K"]

# %% [markdown]
# # Task 6
# Get the statistics of age for each type of education. Use `groupby` and `describe` for this.

# %%
people_education = people.groupby("education")["age"].describe()

# %% [markdown]
# # Task 7
# Compare the married and non-married men salaries. Who earns more? (>50K or <=50K)
# Married men are those, whom `marital-status` starts with "Married". Others are not.

# %%
men = people[people["sex"] == "Male"]

people_married_men = men[men["marital-status"].str.startswith("Married")]

people_not_married_men = men[~men["marital-status"].str.startswith("Married")]

married_rich = (people_married_men["salary"] == ">50K").sum()
not_married_rich = (people_not_married_men["salary"] == ">50K").sum()

married_rich_pct = (people_married_men["salary"] == ">50K").mean() * 100
not_married_rich_pct = (people_not_married_men["salary"] == ">50K").mean() * 100

print(f"Married men earning >50K: {married_rich} ({married_rich_pct:.2f}%)")
print(f"Unmarried men earning >50K: {not_married_rich} ({not_married_rich_pct:.2f}%)")

# %% [markdown]
# # Task 8
# Get the max hours per week some person works. How many people works the same amount of hours per week?

# %%
max_hours = people["hours-per-week"].max()
num_people_max_hours = (people["hours-per-week"] == max_hours).sum()

# %% [markdown]
# # Task 9
# Analyze the correlation between data in dataset. Understand connected fields in it and print highlight thier connection.

# %%
numeric_cols = people.select_dtypes(include="number")
correlation_with_salary = numeric_cols.corr()["salary K$"].sort_values(ascending=False)
print(correlation_with_salary)
